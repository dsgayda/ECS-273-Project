# %%
import datetime as dt
import pandas as pd
import numpy as np

# %% [markdown]
# The data was scraped from the Gun Violence Archive by github user jamesqo. It contains data for all recorded gun violence incidents in the US between January 2013 and March 2018, with the notable exception of the 2017 Vegas mass shooting. 2013 wasn't a reliable scrape
#
# Gun Violence Archive: https://www.gunviolencearchive.org/
#
# Github Repository: https://github.com/jamesqo/gun-violence-data

# %%
gun_violence_filepath = "gun_violence_data.csv"
df = pd.read_csv(gun_violence_filepath)
df['year'] = pd.DatetimeIndex(df['date']).year
df = df[df.state != 'District of Columbia']
df = df[df.year > 2013]
df.reset_index(inplace=True)
df.head()
# Out:
#    index  incident_id        date       state city_or_county  \
# 0    278        95289  2014-01-01    Michigan       Muskegon
# 1    279        92401  2014-01-01  New Jersey         Newark
# 2    280        92383  2014-01-01    New York         Queens
# 3    281        92142  2014-01-01    New York       Brooklyn
# 4    282        95261  2014-01-01    Missouri    Springfield
#
#                        address  n_killed  n_injured  \
# 0  300 block of Monroe Avenue          0          0
# 1               Central Avenue         0          0
# 2                 113th Avenue         1          0
# 3              St. Johns Place         0          1
# 4     Beverly Hills and Temple         0          1
#
#                                        incident_url  \
# 0  http://www.gunviolencearchive.org/incident/95289
# 1  http://www.gunviolencearchive.org/incident/92401
# 2  http://www.gunviolencearchive.org/incident/92383
# 3  http://www.gunviolencearchive.org/incident/92142
# 4  http://www.gunviolencearchive.org/incident/95261
#
#                                           source_url  ...  \
# 0  http://www.mlive.com/news/muskegon/index.ssf/2...  ...
# 1  http://www.nj.com/essex/index.ssf/2014/01/newa...  ...
# 2  http://www.timesledger.com/stories/2014/2/firs...  ...
# 3  http://www.nydailynews.com/new-york/nyc-crime/...  ...
# 4  http://www.ozarksfirst.com/story/deputies-6-ye...  ...
#
#           participant_age_group  participant_gender  \
# 0                  0::Adult 18+           0::Female
# 1                           NaN                 NaN
# 2    0::Adult 18+||1::Adult 18+    0::Male||1::Male
# 3    0::Adult 18+||1::Adult 18+    0::Male||1::Male
# 4  0::Child 0-11||1::Teen 12-17           0::Female
#
#                   participant_name participant_relationship  \
# 0                              NaN                      NaN
# 1                              NaN                      NaN
# 2  0::Julio Mora||1::Sheldon Smith                      NaN
# 3                              NaN                      NaN
# 4                              NaN                      NaN
#
#         participant_status               participant_type  \
# 0              0::Unharmed                      0::Victim
# 1                      NaN                            NaN
# 2   0::Killed||1::Unharmed  0::Victim||1::Subject-Suspect
# 3               0::Injured  0::Victim||1::Subject-Suspect
# 4  0::Injured||1::Unharmed  0::Victim||1::Subject-Suspect
#
#                                              sources  state_house_district  \
# 0  http://www.mlive.com/news/muskegon/index.ssf/2...                  92.0
# 1  http://www.nj.com/essex/index.ssf/2014/01/newa...                  29.0
# 2  http://www.timesledger.com/stories/2014/2/firs...                  33.0
# 3  http://www.nydailynews.com/new-york/nyc-crime/...                  43.0
# 4  http://www.ozarksfirst.com/story/deputies-6-ye...                 131.0
#
#    state_senate_district  year
# 0                   34.0  2014
# 1                   29.0  2014
# 2                   14.0  2014
# 3                   20.0  2014
# 4                   30.0  2014
#
# [5 rows x 31 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 236210 entries, 0 to 236209
# Data columns (total 31 columns):
#  #   Column                       Non-Null Count   Dtype
# ---  ------                       --------------   -----
#  0   index                        236210 non-null  int64
#  1   incident_id                  236210 non-null  int64
#  2   date                         236210 non-null  object
#  3   state                        236210 non-null  object
#  4   city_or_county               236210 non-null  object
#  5   address                      219870 non-null  object
#  6   n_killed                     236210 non-null  int64
#  7   n_injured                    236210 non-null  int64
#  8   incident_url                 236210 non-null  object
#  9   source_url                   235753 non-null  object
#  10  incident_url_fields_missing  236210 non-null  bool
#  11  congressional_district       224812 non-null  float64
#  12  gun_stolen                   138348 non-null  object
#  13  gun_type                     138391 non-null  object
#  14  incident_characteristics     235888 non-null  object
#  15  latitude                     228389 non-null  float64
#  16  location_description         41888 non-null   object
#  17  longitude                    228389 non-null  float64
#  18  n_guns_involved              138391 non-null  float64
#  19  notes                        157710 non-null  object
#  20  participant_age              146512 non-null  object
#  21  participant_age_group        195394 non-null  object
#  22  participant_gender           201308 non-null  object
#  23  participant_name             116640 non-null  object
#  24  participant_relationship     15718 non-null   object
#  25  participant_status           209571 non-null  object
#  26  participant_type             212200 non-null  object
#  27  sources                      235621 non-null  object
#  28  state_house_district         200652 non-null  float64
#  29  state_senate_district        207081 non-null  float64
#  30  year                         236210 non-null  int64
# dtypes: bool(1), float64(6), int64(5), object(19)
# memory usage: 54.3+ MB

# %% [markdown]
# ## Extracting Useful Data as Booleans

# %% [markdown]
# The original dataframe has most of its data stored as strings that make it really hard to filter the data using pandas' built in methods. Therefore I had to do the costly process of going through every row in the "incident characteristics" column and extract useful information to store in a new column as booleans.

# %%
df.incident_characteristics[1]
# Out:
# 'Officer Involved Incident'

# %%
"Gang involvement" in df.incident_characteristics[1]
# Out:
# False

# %%
# parsing data for keywords

suicide = [False] * len(df)
mass_shooting = [False] * len(df)
gang = [False] * len(df)
wounded = [False] * len(df)
dead = [False] * len(df)

for i in range(len(df.incident_characteristics)):
    if pd.isna(df.incident_characteristics.iloc[i]) == False:
        if "mass shooting" in df.incident_characteristics[i].lower():
            mass_shooting[i] = True
        if "suicide" in df.incident_characteristics[i].lower():
            suicide[i] = True
        if "gang involvement" in df.incident_characteristics[i].lower():
            gang[i] = True
        if "dead" in df.incident_characteristics[i].lower():
            dead[i] = True
        if "wounded" in df.incident_characteristics[i].lower():
            wounded[i] = True
            
df["suicide"] = suicide
df["mass shooting"] = mass_shooting
df["gang"] = gang
df["wounded"] = wounded
df["dead"] = dead
df.head()
# Out:
#    index  incident_id        date       state city_or_county  \
# 0    278        95289  2014-01-01    Michigan       Muskegon
# 1    279        92401  2014-01-01  New Jersey         Newark
# 2    280        92383  2014-01-01    New York         Queens
# 3    281        92142  2014-01-01    New York       Brooklyn
# 4    282        95261  2014-01-01    Missouri    Springfield
#
#                        address  n_killed  n_injured  \
# 0  300 block of Monroe Avenue          0          0
# 1               Central Avenue         0          0
# 2                 113th Avenue         1          0
# 3              St. Johns Place         0          1
# 4     Beverly Hills and Temple         0          1
#
#                                        incident_url  \
# 0  http://www.gunviolencearchive.org/incident/95289
# 1  http://www.gunviolencearchive.org/incident/92401
# 2  http://www.gunviolencearchive.org/incident/92383
# 3  http://www.gunviolencearchive.org/incident/92142
# 4  http://www.gunviolencearchive.org/incident/95261
#
#                                           source_url  ...  \
# 0  http://www.mlive.com/news/muskegon/index.ssf/2...  ...
# 1  http://www.nj.com/essex/index.ssf/2014/01/newa...  ...
# 2  http://www.timesledger.com/stories/2014/2/firs...  ...
# 3  http://www.nydailynews.com/new-york/nyc-crime/...  ...
# 4  http://www.ozarksfirst.com/story/deputies-6-ye...  ...
#
#                 participant_type  \
# 0                      0::Victim
# 1                            NaN
# 2  0::Victim||1::Subject-Suspect
# 3  0::Victim||1::Subject-Suspect
# 4  0::Victim||1::Subject-Suspect
#
#                                              sources state_house_district  \
# 0  http://www.mlive.com/news/muskegon/index.ssf/2...                 92.0
# 1  http://www.nj.com/essex/index.ssf/2014/01/newa...                 29.0
# 2  http://www.timesledger.com/stories/2014/2/firs...                 33.0
# 3  http://www.nydailynews.com/new-york/nyc-crime/...                 43.0
# 4  http://www.ozarksfirst.com/story/deputies-6-ye...                131.0
#
#   state_senate_district  year  suicide mass shooting   gang  wounded   dead
# 0                  34.0  2014    False         False  False    False  False
# 1                  29.0  2014    False         False  False    False  False
# 2                  14.0  2014     True         False  False    False   True
# 3                  20.0  2014    False         False  False     True  False
# 4                  30.0  2014    False         False  False     True  False
#
# [5 rows x 36 columns]

# %%
df[df["mass shooting"]==True].head()
# Out:
#       index  incident_id        date      state city_or_county  \
# 72      351        92194  2014-01-01   Virginia        Norfolk
# 325     614        92704  2014-01-03   New York         Queens
# 1486   1803        95500  2014-01-12  Louisiana       Tallulah
# 1513   1831        95579  2014-01-12   Illinois          Elgin
# 1573   1891        95550  2014-01-12    Alabama     Huntsville
#
#                                             address  n_killed  n_injured  \
# 72    Rockingham Street and Berkley Avenue Extended         2          2
# 325              Farmers Boulevard and 133rd Avenue         1          3
# 1486                     3600 block of Highway 80 W         0          6
# 1513                      300 block of North Street         0          5
# 1573                               University Drive         0          5
#
#                                           incident_url  \
# 72    http://www.gunviolencearchive.org/incident/92194
# 325   http://www.gunviolencearchive.org/incident/92704
# 1486  http://www.gunviolencearchive.org/incident/95500
# 1513  http://www.gunviolencearchive.org/incident/95579
# 1573  http://www.gunviolencearchive.org/incident/95550
#
#                                              source_url  ...  \
# 72    http://www.dailypress.com/news/crime/dp-norfol...  ...
# 325                   http://abclocal.go.com/wabc/story  ...
# 1486  http://www.myarklamiss.com/crime/update-3-new-...  ...
# 1513  http://www.chicagotribune.com/news/local/break...  ...
# 1573  http://blog.al.com/breaking/2014/01/huntsville...  ...
#
#                                        participant_type  \
# 72           0::Victim||1::Victim||2::Victim||3::Victim
# 325   0::Victim||1::Victim||2::Victim||3::Victim||4:...
# 1486  0::Victim||1::Victim||2::Victim||3::Victim||4:...
# 1513  0::Victim||1::Victim||2::Victim||3::Victim||4:...
# 1573  0::Victim||1::Victim||2::Victim||3::Victim||4:...
#
#                                                 sources state_house_district  \
# 72    http://www.dailypress.com/news/crime/dp-norfol...                 80.0
# 325   http://www.nydailynews.com/new-york/nyc-crime/...                 32.0
# 1486  http://www.ksla.com/story/24428661/6-hurt-in-m...                 19.0
# 1513  http://www.chicagotribune.com/news/local/break...                 43.0
# 1573  http://www.waff.com/story/24426895/shooting-se...                 53.0
#
#      state_senate_district  year  suicide mass shooting   gang  wounded   dead
# 72                     6.0  2014     True          True  False     True   True
# 325                   10.0  2014     True          True  False     True   True
# 1486                  34.0  2014    False          True  False     True  False
# 1513                  22.0  2014    False          True  False     True  False
# 1573                   2.0  2014    False          True  False     True  False
#
# [5 rows x 36 columns]

# %%
df.to_pickle("gunviolence.pickle")

# %% [markdown]
# ## Changing Index to Datetime

# %%
# # change index to datetime index
# newDate = pd.to_datetime(df.date)
# df.drop(columns=["date"], inplace=True)
# df.set_index(newDate, inplace=True)
# df["2015"].head()

# %%
# df = df[df.latitude != np.nan]
# df = df[df.longitude != np.nan]

# %%
# df.to_pickle("gunviolence.pickle")
