# %%
import pandas as pd

# %%
corr_filepath = 'data/policy_incident_correlations.csv'

df = pd.read_csv(corr_filepath)

# %% [markdown]
# # All Incidents

# %%
df.sort_values('all_incidents', ascending=True)[['category', 'category_type', 'all_incidents']][:10]
# Out:
#                              category category_type  all_incidents
# 44                       Registration   subcategory      -0.244537
# 38                 Misdemeanor crimes   subcategory      -0.222615
# 46                          Reporting   subcategory      -0.191727
# 30    Gun violence restraining orders   subcategory      -0.188981
# 7                   Domestic violence      category      -0.174739
# 19  Background checks - state records   subcategory      -0.149136
# 11                         Preemption      category      -0.142280
# 0                                 all        policy      -0.137525
# 4                   Buyer regulations      category      -0.135100
# 27                     Fingerprinting   subcategory      -0.132898

# %% [markdown]
# # Mass Shootings

# %%
df.sort_values('mass_shooting', ascending=True)[['category', 'category_type', 'mass_shooting']][:10]
# Out:
#                              category category_type  mass_shooting
# 56        Universal background checks   subcategory      -0.191949
# 14                   Age restrictions   subcategory      -0.191894
# 26                             Felony   subcategory      -0.175263
# 51                           Security   subcategory      -0.172013
# 46                          Reporting   subcategory      -0.164780
# 33        Large capacity magazine ban   subcategory      -0.154562
# 35                          Licensing   subcategory      -0.147037
# 44                       Registration   subcategory      -0.144082
# 3                   Background checks      category      -0.135149
# 20  Background checks through permits   subcategory      -0.133766

# %% [markdown]
# # Suicides

# %%
df.sort_values('suicides', ascending=True)[['category', 'category_type', 'suicides']][:10]
# Out:
#                              category category_type  suicides
# 13                  Stand your ground      category -0.326011
# 9                            Immunity      category -0.314155
# 38                 Misdemeanor crimes   subcategory -0.294690
# 14                   Age restrictions   subcategory -0.267905
# 20  Background checks through permits   subcategory -0.266799
# 19  Background checks - state records   subcategory -0.264459
# 0                                 all        policy -0.263640
# 7                   Domestic violence      category -0.259826
# 11                         Preemption      category -0.258904
# 4                   Buyer regulations      category -0.250143

# %% [markdown]
# # Non-Suicides

# %%
df.sort_values('non_suicides', ascending=True)[['category', 'category_type', 'non_suicides']][:10]
# Out:
#                                         category category_type  non_suicides
# 44                                  Registration   subcategory     -0.232123
# 38                            Misdemeanor crimes   subcategory     -0.187348
# 30               Gun violence restraining orders   subcategory     -0.178045
# 46                                     Reporting   subcategory     -0.169276
# 7                              Domestic violence      category     -0.138953
# 27                                Fingerprinting   subcategory     -0.113263
# 33                   Large capacity magazine ban   subcategory     -0.110287
# 19             Background checks - state records   subcategory     -0.106458
# 24                      Crime gun identification   subcategory     -0.103156
# 2   Assault weapons and large-capacity magazines      category     -0.100461
