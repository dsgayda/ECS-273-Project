# %%
import pandas as pd

# %% [markdown]
# State populations retrieved from https://www.census.gov/programs-surveys/popest/technical-documentation/research/evaluation-estimates/2020-evaluation-estimates/2010s-state-total.html

# %%
# gun_violence_filepath = "data/gunviolence.pickle"
# policy_filepath = "data/policy_metadata.csv"
population_filepath = "nst-est2020.xlsx"

# gun_violence_df = pd.read_pickle(gun_violence_filepath)
# policy_df = pd.read_csv(policy_filepath)
population_df = pd.read_excel(population_filepath, header=3, skiprows=[62, 63, 64, 65, 66, 67])

# %%
population_df
# Out:
#                Unnamed: 0       Census  Estimates Base         2010  \
# 0           United States  308745538.0     308758105.0  309327143.0
# 1               Northeast   55317240.0      55318414.0   55380764.0
# 2                 Midwest   66927001.0      66929737.0   66975328.0
# 3                   South  114555744.0     114563042.0  114869421.0
# 4                    West   71945553.0      71946912.0   72101630.0
# 5                .Alabama    4779736.0       4780118.0    4785514.0
# 6                 .Alaska     710231.0        710246.0     713982.0
# 7                .Arizona    6392017.0       6392292.0    6407342.0
# 8               .Arkansas    2915918.0       2916029.0    2921998.0
# 9             .California   37253956.0      37254522.0   37319550.0
# 10              .Colorado    5029196.0       5029319.0    5047539.0
# 11           .Connecticut    3574097.0       3574151.0    3579173.0
# 12              .Delaware     897934.0        897947.0     899647.0
# 13  .District of Columbia     601723.0        601767.0     605282.0
# 14               .Florida   18801310.0      18804589.0   18846143.0
# 15               .Georgia    9687653.0       9688737.0    9712209.0
# 16                .Hawaii    1360301.0       1360304.0    1364004.0
# 17                 .Idaho    1567582.0       1567658.0    1570819.0
# 18              .Illinois   12830632.0      12831572.0   12840545.0
# 19               .Indiana    6483802.0       6484050.0    6490555.0
# 20                  .Iowa    3046355.0       3046877.0    3050819.0
# 21                .Kansas    2853118.0       2853120.0    2858266.0
# 22              .Kentucky    4339367.0       4339330.0    4348464.0
# 23             .Louisiana    4533372.0       4533500.0    4544635.0
# 24                 .Maine    1328361.0       1328354.0    1327651.0
# 25              .Maryland    5773552.0       5773787.0    5788784.0
# 26         .Massachusetts    6547629.0       6547788.0    6566440.0
# 27              .Michigan    9883640.0       9884112.0    9877597.0
# 28             .Minnesota    5303925.0       5303933.0    5310934.0
# 29           .Mississippi    2967297.0       2968129.0    2970615.0
# 30              .Missouri    5988927.0       5988941.0    5996089.0
# 31               .Montana     989415.0        989400.0     990730.0
# 32              .Nebraska    1826341.0       1826311.0    1829591.0
# 33                .Nevada    2700551.0       2700683.0    2702483.0
# 34         .New Hampshire    1316470.0       1316457.0    1316807.0
# 35            .New Jersey    8791894.0       8791959.0    8799451.0
# 36            .New Mexico    2059179.0       2059199.0    2064614.0
# 37              .New York   19378102.0      19378117.0   19399956.0
# 38        .North Carolina    9535483.0       9535762.0    9574586.0
# 39          .North Dakota     672591.0        672575.0     674752.0
# 40                  .Ohio   11536504.0      11536763.0   11539449.0
# 41              .Oklahoma    3751351.0       3751582.0    3760014.0
# 42                .Oregon    3831074.0       3831083.0    3837614.0
# 43          .Pennsylvania   12702379.0      12702891.0   12711406.0
# 26    6893574.0
# 27    9966555.0
# 28    5657342.0
# 29    2966786.0
# 30    6151548.0
# 31    1080577.0
# 32    1937552.0
# 33    3138259.0
# 34    1366275.0
# 35    8882371.0
# 36    2106319.0
# 37   19336776.0
# 38   10600823.0
# 39     765309.0
# 40   11693217.0
# 41    3980783.0
# 42    4241507.0
# 43   12783254.0
# 44    1057125.0
# 45    5218040.0
# 46     892717.0
# 47    6886834.0
# 48   29360759.0
# 49    3249879.0
# 50     623347.0
# 51    8590563.0
# 52    7693612.0
# 53    1784787.0
# 54    5832655.0
# 55     582328.0
# 56          NaN
# 57    3159343.0

# %%
# preprocess population data
population_df.rename(columns={'July 1': 2020}, inplace=True)
population_df.dropna(inplace=True)
population_df['state'] = population_df['Unnamed: 0'].str.replace('[^\w\s]','')
population_df = pd.melt(population_df, id_vars=['state'], value_vars=[2014, 2015, 2016, 2017, 2018, 2019, 2020])
population_df.rename(columns={'variable': 'year', 'value':'population'}, inplace=True)
population_df.set_index(['year', 'state'])
population_df[:5]
# Out:
# <ipython-input-5-d9dba26e2039>:4: FutureWarning: The default value of regex will change from True to False in a future version.
#   population_df['state'] = population_df['Unnamed: 0'].str.replace('[^\w\s]','')
#            state  year   population
# 0  United States  2014  318386329.0
# 1      Northeast  2014   56021339.0
# 2        Midwest  2014   67765576.0
# 3          South  2014  119666248.0
# 4           West  2014   74933166.0

# %%
gun_violence_df[:5]
# Out:
#    index  incident_id        date       state city_or_county  \
# 0    278        95289  2014-01-01    Michigan       Muskegon
# 1    279        92401  2014-01-01  New Jersey         Newark
# 2    280        92383  2014-01-01    New York         Queens
# 3    281        92142  2014-01-01    New York       Brooklyn
# 4    282        95261  2014-01-01    Missouri    Springfield
#
#                        address  n_killed  n_injured  \
# 0  300 block of Monroe Avenue          0          0
# 1               Central Avenue         0          0
# 2                 113th Avenue         1          0
# 3              St. Johns Place         0          1
# 4     Beverly Hills and Temple         0          1
#
#                                        incident_url  \
# 0  http://www.gunviolencearchive.org/incident/95289
# 1  http://www.gunviolencearchive.org/incident/92401
# 2  http://www.gunviolencearchive.org/incident/92383
# 3  http://www.gunviolencearchive.org/incident/92142
# 4  http://www.gunviolencearchive.org/incident/95261
#
#                                           source_url  ...  \
# 0  http://www.mlive.com/news/muskegon/index.ssf/2...  ...
# 1  http://www.nj.com/essex/index.ssf/2014/01/newa...  ...
# 2  http://www.timesledger.com/stories/2014/2/firs...  ...
# 3  http://www.nydailynews.com/new-york/nyc-crime/...  ...
# 4  http://www.ozarksfirst.com/story/deputies-6-ye...  ...
#
#                 participant_type  \
# 0                      0::Victim
# 1                            NaN
# 2  0::Victim||1::Subject-Suspect
# 3  0::Victim||1::Subject-Suspect
# 4  0::Victim||1::Subject-Suspect
#
#                                              sources state_house_district  \
# 0  http://www.mlive.com/news/muskegon/index.ssf/2...                 92.0
# 1  http://www.nj.com/essex/index.ssf/2014/01/newa...                 29.0
# 2  http://www.timesledger.com/stories/2014/2/firs...                 33.0
# 3  http://www.nydailynews.com/new-york/nyc-crime/...                 43.0
# 4  http://www.ozarksfirst.com/story/deputies-6-ye...                131.0
#
#   state_senate_district  year  suicide mass shooting   gang  wounded   dead
# 0                  34.0  2014    False         False  False    False  False
# 1                  29.0  2014    False         False  False    False  False
# 2                  14.0  2014     True         False  False    False   True
# 3                  20.0  2014    False         False  False     True  False
# 4                  30.0  2014    False         False  False     True  False
#
# [5 rows x 36 columns]

# %%
policy_df[:5]
# Out:
#    year    state                                      category  \
# 0  2014  Alabama                        Ammunition regulations
# 1  2014  Alabama                        Ammunition regulations
# 2  2014  Alabama  Assault weapons and large-capacity magazines
# 3  2014  Alabama  Assault weapons and large-capacity magazines
# 4  2014  Alabama                             Background checks
#
#                   sub_category  policies_implemented
# 0            Background checks                     3
# 1                  Prohibitors                     0
# 2          Assault weapons ban                     0
# 3  Large capacity magazine ban                     0
# 4                    Gun shows                     0

# %% [markdown]
# # Correlation Between Incident Types and Total Number of Policies

# %%
# all incidents
all_incidents = pd.DataFrame(gun_violence_df.groupby(['year', 'state']).size()).join(
                                policy_df[['year', 'state', 'policies_implemented']].groupby(
                                    ['year', 'state']).sum())
all_incidents['population'] = list(all_incidents.merge(population_df, on=['year', 'state'], how='left')['population'])

all_incidents.rename(columns={0:'gun_violence_incidents'}, inplace=True)
all_incidents['incidents_per_capita'] = all_incidents.gun_violence_incidents / all_incidents.population
all_incidents.reset_index(inplace=True)
all_incidents
# Out:
#      year          state  gun_violence_incidents  policies_implemented  \
# 0    2014        Alabama                    1318                    10
# 1    2014         Alaska                     146                     3
# 2    2014        Arizona                     556                     8
# 3    2014       Arkansas                     572                    11
# 4    2014     California                    3732                   100
# ..    ...            ...                     ...                   ...
# 245  2018       Virginia                     293                    13
# 246  2018     Washington                     200                    43
# 247  2018  West Virginia                      80                    18
# 248  2018      Wisconsin                     376                    23
# 249  2018        Wyoming                      14                     7
#
#      population  incidents_per_capita
# 0     4843737.0              0.000272
# 1      737075.0              0.000198
# 2     6732873.0              0.000083
# 3     2968759.0              0.000193
# 4    38586706.0              0.000097
# ..          ...                   ...
# 245   8510920.0              0.000034
# 246   7526793.0              0.000027
# 247   1805953.0              0.000044
# 248   5809319.0              0.000065
# 249    579054.0              0.000024
#
# [250 rows x 6 columns]

# %%
all_incidents.corr()
# Out:
#                             year  gun_violence_incidents  \
# year                    1.000000               -0.193660
# gun_violence_incidents -0.193660                1.000000
# policies_implemented    0.020426                0.291116
# population              0.008346                0.734572
# incidents_per_capita   -0.345511                0.323411
#
#                         policies_implemented  population  incidents_per_capita
# year                                0.020426    0.008346             -0.345511
# gun_violence_incidents              0.291116    0.734572              0.323411
# policies_implemented                1.000000    0.432655             -0.137525
# population                          0.432655    1.000000             -0.160069
# incidents_per_capita               -0.137525   -0.160069              1.000000

# %%
all_incidents.corr().iloc[2,4]
# Out:
# -0.1375245458063732

# %%
# suicides
suicides = pd.DataFrame(gun_violence_df[gun_violence_df.suicide].groupby(['year', 'state']).size()).join(
                                policy_df[['year', 'state', 'policies_implemented']].groupby(
                                    ['year', 'state']).sum())
suicides['population'] = list(suicides.merge(population_df, on=['year', 'state'], how='left')['population'])

suicides.rename(columns={0:'gun_violence_incidents'}, inplace=True)
suicides['incidents_per_capita'] = suicides.gun_violence_incidents / suicides.population
suicides.reset_index(inplace=True)

# non-suicides
non_suicides = pd.DataFrame(gun_violence_df[gun_violence_df.suicide != True].groupby(['year', 'state']).size()).join(
                                policy_df[['year', 'state', 'policies_implemented']].groupby(
                                    ['year', 'state']).sum())

non_suicides['population'] = list(non_suicides.merge(population_df, on=['year', 'state'], how='left')['population'])

non_suicides.rename(columns={0:'gun_violence_incidents'}, inplace=True)
non_suicides['incidents_per_capita'] = non_suicides.gun_violence_incidents / non_suicides.population
non_suicides.reset_index(inplace=True)

# mass-shootings
mass_shooting = pd.DataFrame(gun_violence_df[gun_violence_df['mass shooting']].groupby(['year', 'state']).size()).join(
                                policy_df[['year', 'state', 'policies_implemented']].groupby(
                                    ['year', 'state']).sum())

mass_shooting['population'] = list(mass_shooting.merge(population_df, on=['year', 'state'], how='left')['population'])

mass_shooting.rename(columns={0:'gun_violence_incidents'}, inplace=True)
mass_shooting['incidents_per_capita'] = mass_shooting.gun_violence_incidents / mass_shooting.population
mass_shooting.reset_index(inplace=True)

# %% [markdown]
# ## Examining Correlations

# %%
correlation_dfs = []

policy_correlations = {'category': ['all']*4,
                       'incidence_type': ['all_incidents', 'suicides', 'non_suicides', 'mass_shooting'], 
                       'corr': [all_incidents.corr().iloc[2,4], 
                               suicides.corr().iloc[2,4],
                               non_suicides.corr().iloc[2,4],
                               mass_shooting.corr().iloc[2,4],]}

all_policy_correlation_df = pd.DataFrame(policy_correlations).pivot(index='category', columns='incidence_type', values='corr')
all_policy_correlation_df['category_type'] = 'policy'
correlation_dfs.append(all_policy_correlation_df)

all_policy_correlation_df
# Out:
# incidence_type  all_incidents  mass_shooting  non_suicides  suicides  \
# category
# all                 -0.137525      -0.126371     -0.092551  -0.26364
#
# incidence_type category_type
# category
# all                   policy

# %% [markdown]
# # Correlation Between Incident Types and Policy Categories

# %%
# all incidents
all_incidents = pd.DataFrame(gun_violence_df.groupby(['year', 'state']).size()).join(
                                policy_df[['year', 'state','category', 'policies_implemented']].groupby(
                                    ['year', 'state', 'category']).sum())
all_incidents['population'] = list(all_incidents.merge(population_df, on=['year', 'state'], how='left')['population'])

all_incidents.rename(columns={0:'gun_violence_incidents'}, inplace=True)
all_incidents['incidents_per_capita'] = all_incidents.gun_violence_incidents / all_incidents.population
all_incidents.reset_index(inplace=True)

policy_correlations = {'category': [], 'incidence_type': [], 'corr': []}
corr_categories = set(all_incidents.category)

for category in corr_categories:
    df_category = all_incidents[all_incidents.category == category]
    df_category_corr = df_category.corr()
    policy_correlations['category'].append(category)
    policy_correlations['incidence_type'].append('all_incidents')
    policy_correlations['corr'].append(df_category_corr.iloc[2,4])

# suicides
suicides = pd.DataFrame(gun_violence_df[gun_violence_df.suicide].groupby(['year', 'state']).size()).join(
                                policy_df[['year', 'state','category', 'policies_implemented']].groupby(
                                    ['year', 'state', 'category']).sum())
suicides['population'] = list(suicides.merge(population_df, on=['year', 'state'], how='left')['population'])

suicides.rename(columns={0:'gun_violence_incidents'}, inplace=True)
suicides['incidents_per_capita'] = suicides.gun_violence_incidents / suicides.population
suicides.reset_index(inplace=True)

for category in corr_categories:
    df_category = suicides[suicides.category == category]
    df_category_corr = df_category.corr()
    policy_correlations['category'].append(category)
    policy_correlations['incidence_type'].append('suicides')
    policy_correlations['corr'].append(df_category_corr.iloc[2,4])
    
# non-suicides
non_suicides = pd.DataFrame(gun_violence_df[gun_violence_df.suicide != True].groupby(['year', 'state']).size()).join(
                                policy_df[['year', 'state','category', 'policies_implemented']].groupby(
                                    ['year', 'state', 'category']).sum())

non_suicides['population'] = list(non_suicides.merge(population_df, on=['year', 'state'], how='left')['population'])

non_suicides.rename(columns={0:'gun_violence_incidents'}, inplace=True)
non_suicides['incidents_per_capita'] = non_suicides.gun_violence_incidents / non_suicides.population
non_suicides.reset_index(inplace=True)

for category in corr_categories:
    df_category = non_suicides[non_suicides.category == category]
    df_category_corr = df_category.corr()
    policy_correlations['category'].append(category)
    policy_correlations['incidence_type'].append('non_suicides')
    policy_correlations['corr'].append(df_category_corr.iloc[2,4])

# mass shootings
mass_shooting = pd.DataFrame(gun_violence_df[gun_violence_df['mass shooting']].groupby(['year', 'state']).size()).join(
                                policy_df[['year', 'state','category', 'policies_implemented']].groupby(
                                    ['year', 'state', 'category']).sum())

mass_shooting['population'] = list(mass_shooting.merge(population_df, on=['year', 'state'], how='left')['population'])

mass_shooting.rename(columns={0:'gun_violence_incidents'}, inplace=True)
mass_shooting['incidents_per_capita'] = mass_shooting.gun_violence_incidents / mass_shooting.population
mass_shooting.reset_index(inplace=True)

for category in corr_categories:
    df_category = mass_shooting[mass_shooting.category == category]
    df_category_corr = df_category.corr()
    policy_correlations['category'].append(category)
    policy_correlations['incidence_type'].append('mass_shooting')
    policy_correlations['corr'].append(df_category_corr.iloc[2,4])

# %% [markdown]
# ## Examining Correlations

# %%
policy_category_correlation_df = pd.DataFrame(policy_correlations).pivot(
                                    index='category', columns='incidence_type', values='corr')
policy_category_correlation_df['category_type'] = 'category'
correlation_dfs.append(policy_category_correlation_df)

policy_category_correlation_df
# Out:
# incidence_type                                all_incidents  mass_shooting  \
# category
# Ammunition regulations                            -0.015377      -0.010841
# Assault weapons and large-capacity magazines      -0.119296      -0.131916
# Background checks                                 -0.094928      -0.135149
# Buyer regulations                                 -0.135100      -0.120317
# Child access prevention                           -0.089089      -0.122454
# Dealer regulations                                -0.100895      -0.124211
# Domestic violence                                 -0.174739      -0.100594
# Gun trafficking                                   -0.065531      -0.094347
# Immunity                                          -0.124037      -0.070757
# Possession regulations                            -0.023057       0.041204
# Preemption                                        -0.142280      -0.104066
# Prohibitions for high-risk gun possession         -0.120453      -0.123877
# Stand your ground                                 -0.090064      -0.120040
#
# incidence_type                                non_suicides  suicides  \
# category
# Ammunition regulations                           -0.026483  0.027300
# Assault weapons and large-capacity magazines     -0.100461 -0.157692
# Background checks                                -0.048042 -0.237733
# Buyer regulations                                -0.093434 -0.250143
# Child access prevention                          -0.044811 -0.224082
# Dealer regulations                               -0.054113 -0.241937
# Domestic violence                                -0.138953 -0.259826
# Gun trafficking                                  -0.032881 -0.165109
# Immunity                                         -0.061771 -0.314155
# Possession regulations                           -0.008034 -0.070533
# Preemption                                       -0.099689 -0.258904
# Prohibitions for high-risk gun possession        -0.089777 -0.200246
# Stand your ground                                -0.017032 -0.326011
#
# incidence_type                               category_type
# category
# Ammunition regulations                            category
# Assault weapons and large-capacity magazines      category
# Background checks                                 category
# Buyer regulations                                 category
# Child access prevention                           category
# Dealer regulations                                category
# Domestic violence                                 category
# Gun trafficking                                   category
# Immunity                                          category
# Possession regulations                            category
# Preemption                                        category
# Prohibitions for high-risk gun possession         category
# Stand your ground                                 category

# %% [markdown]
# # Correlation Between Incident Types and Policy Subcategories

# %%
# all incidents
all_incidents = pd.DataFrame(gun_violence_df.groupby(['year', 'state']).size()).join(
                                policy_df[['year', 'state','sub_category', 'policies_implemented']].groupby(
                                    ['year', 'state', 'sub_category']).sum())
all_incidents['population'] = list(all_incidents.merge(population_df, on=['year', 'state'], how='left')['population'])

all_incidents.rename(columns={0:'gun_violence_incidents'}, inplace=True)
all_incidents['incidents_per_capita'] = all_incidents.gun_violence_incidents / all_incidents.population
all_incidents.reset_index(inplace=True)


policy_correlations = {'category': [], 'incidence_type': [], 'corr': []}
# some categories only have one subcategory, in which case we get duplicate results
# so I'm removing those
corr_categories = list(set(all_incidents.sub_category) - set(policy_df.category)) 

for category in corr_categories:
    df_category = all_incidents[all_incidents.sub_category == category]
    df_category_corr = df_category.corr()
    policy_correlations['category'].append(category)
    policy_correlations['incidence_type'].append('all_incidents')
    policy_correlations['corr'].append(df_category_corr.iloc[2,4])

# suicides
suicides = pd.DataFrame(gun_violence_df[gun_violence_df.suicide].groupby(['year', 'state']).size()).join(
                                policy_df[['year', 'state','sub_category', 'policies_implemented']].groupby(
                                    ['year', 'state', 'sub_category']).sum())
suicides['population'] = list(suicides.merge(population_df, on=['year', 'state'], how='left')['population'])

suicides.rename(columns={0:'gun_violence_incidents'}, inplace=True)
suicides['incidents_per_capita'] = suicides.gun_violence_incidents / suicides.population
suicides.reset_index(inplace=True)

for category in corr_categories:
    df_category = suicides[suicides.sub_category == category]
    df_category_corr = df_category.corr()
    policy_correlations['category'].append(category)
    policy_correlations['incidence_type'].append('suicides')
    policy_correlations['corr'].append(df_category_corr.iloc[2,4])
    
# non-suicides
non_suicides = pd.DataFrame(gun_violence_df[gun_violence_df.suicide != True].groupby(['year', 'state']).size()).join(
                                policy_df[['year', 'state','sub_category', 'policies_implemented']].groupby(
                                    ['year', 'state', 'sub_category']).sum())

non_suicides['population'] = list(non_suicides.merge(population_df, on=['year', 'state'], how='left')['population'])

non_suicides.rename(columns={0:'gun_violence_incidents'}, inplace=True)
non_suicides['incidents_per_capita'] = non_suicides.gun_violence_incidents / non_suicides.population
non_suicides.reset_index(inplace=True)

for category in corr_categories:
    df_category = non_suicides[non_suicides.sub_category == category]
    df_category_corr = df_category.corr()
    policy_correlations['category'].append(category)
    policy_correlations['incidence_type'].append('non_suicides')
    policy_correlations['corr'].append(df_category_corr.iloc[2,4])
    
# mass shootings
mass_shooting = pd.DataFrame(gun_violence_df[gun_violence_df['mass shooting']].groupby(['year', 'state']).size()).join(
                                policy_df[['year', 'state','sub_category', 'policies_implemented']].groupby(
                                    ['year', 'state', 'sub_category']).sum())

mass_shooting['population'] = list(mass_shooting.merge(population_df, on=['year', 'state'], how='left')['population'])

mass_shooting.rename(columns={0:'gun_violence_incidents'}, inplace=True)
mass_shooting['incidents_per_capita'] = mass_shooting.gun_violence_incidents / mass_shooting.population
mass_shooting.reset_index(inplace=True)

for category in corr_categories:
    df_category = mass_shooting[mass_shooting.sub_category == category]
    df_category_corr = df_category.corr()
    policy_correlations['category'].append(category)
    policy_correlations['incidence_type'].append('mass_shooting')
    policy_correlations['corr'].append(df_category_corr.iloc[2,4])

# %% [markdown]
# ## Examining Correlations

# %%
policy_subcategory_correlation_df = pd.DataFrame(policy_correlations).pivot(index='category', 
                                                                            columns='incidence_type', values='corr')
policy_subcategory_correlation_df['category_type'] = 'subcategory'
correlation_dfs.append(policy_subcategory_correlation_df)

policy_subcategory_correlation_df
# Out:
# incidence_type                             all_incidents  mass_shooting  \
# category
# Age restrictions                               -0.120659      -0.191894
# Alcohol                                        -0.024184      -0.043451
# Assault weapons ban                            -0.110243      -0.116110
# Background check records                       -0.087924      -0.127064
# Background checks - mental health records       0.012181      -0.072383
# Background checks - state records              -0.149136      -0.129185
# Background checks through permits              -0.101808      -0.133766
# Background checks time limit                   -0.045844      -0.000179
# Bulk purchase limit                            -0.080827       0.002876
# Campus carry                                    0.111575       0.137035
# Crime gun identification                       -0.093540      -0.076477
# Drugs                                           0.015074      -0.008061
# Felony                                         -0.053726      -0.175263
# Fingerprinting                                 -0.132898      -0.074917
# Firearm removal                                -0.099273       0.015989
# Gun shows                                      -0.037364      -0.084963
# Gun violence restraining orders                -0.188981      -0.085510
# Inspections                                     0.015586      -0.093671
# Junk guns                                      -0.082516       0.068101
# Large capacity magazine ban                    -0.130220      -0.154562
# Liability                                      -0.019058      -0.085116
# Licensing                                      -0.126642      -0.147037
# Location                                        0.015429      -0.109674
# Mental Health                                  -0.118240      -0.121768
# Misdemeanor crimes                             -0.222615      -0.102308
# Open carry                                     -0.101553       0.023672
# Permitting                                     -0.051904      -0.067841
# Personalized gun technology                    -0.015113       0.036679
# Prohibitors                                    -0.007870       0.013768
# Recordkeeping                                   0.017276      -0.028399
# Registration                                   -0.244537      -0.144082
# Relinquishment of weapons                      -0.070264      -0.037796
# Reporting                                      -0.191727      -0.164780
# Restraining order                              -0.124503      -0.088751
# Safety locks                                   -0.089179      -0.102045
# Safety training                                -0.095201      -0.077451
# School zones                                    0.115882      -0.069182
# Security                                       -0.095540      -0.172013
# Stalking                                       -0.093361      -0.107368
# Storage                                        -0.078030      -0.115369
# Straw purchase                                 -0.063754      -0.086835
# Theft reporting                                 0.049796      -0.054231
# Universal background checks                    -0.090115      -0.191949
# Violent Misdemeanor                            -0.125246      -0.042567
# Waiting period                                 -0.116175       0.081847
#
# incidence_type                             non_suicides  suicides  \
# category
# Age restrictions                              -0.070802 -0.267905
# Alcohol                                       -0.030679  0.004323
# Assault weapons ban                           -0.092476 -0.146999
# Background check records                      -0.049695 -0.201900
# Background checks - mental health records      0.055094 -0.141676
# Background checks - state records             -0.106458 -0.264459
# Background checks through permits             -0.048160 -0.266799
# Background checks time limit                  -0.023302 -0.114454
# Bulk purchase limit                           -0.098342 -0.000303
# Campus carry                                   0.106035  0.104992
# Crime gun identification                      -0.103156 -0.037835
# Drugs                                          0.044846 -0.093218
# Felony                                        -0.052640 -0.044988
# Fingerprinting                                -0.113263 -0.170932
# Firearm removal                               -0.099082 -0.076741
# Gun shows                                     -0.002228 -0.152274
# Gun violence restraining orders               -0.178045 -0.183293
# Inspections                                    0.072198 -0.187270
# Junk guns                                     -0.070488 -0.105555
# Large capacity magazine ban                   -0.110287 -0.169927
# Liability                                     -0.003777 -0.068379
# Licensing                                     -0.091571 -0.220454
# Location                                       0.054463 -0.125535
# Mental Health                                 -0.093285 -0.178417
# Misdemeanor crimes                            -0.187348 -0.294690
# Open carry                                    -0.085763 -0.133381
# Permitting                                    -0.009909 -0.187551
# Personalized gun technology                   -0.028825  0.036673
# Prohibitors                                    0.013567 -0.081466
# Recordkeeping                                  0.066016 -0.158275
# Registration                                  -0.232123 -0.231062
# Relinquishment of weapons                     -0.034480 -0.179766
# Reporting                                     -0.169276 -0.225921
# Restraining order                             -0.091706 -0.210817
# Safety locks                                  -0.055861 -0.185577
# Safety training                               -0.059651 -0.198049
# School zones                                   0.139520  0.005615
# Security                                      -0.057137 -0.208348
# Stalking                                      -0.065460 -0.169725
# Storage                                       -0.035278 -0.210238
# Straw purchase                                -0.054749 -0.080540
# Theft reporting                                0.106474 -0.161294
# Universal background checks                   -0.055530 -0.190757
# Violent Misdemeanor                           -0.095209 -0.201672
# Waiting period                                -0.099617 -0.147289
#
# incidence_type                            category_type
# category
# Age restrictions                            subcategory
# Alcohol                                     subcategory
# Assault weapons ban                         subcategory
# Background check records                    subcategory
# Background checks - mental health records   subcategory
# Background checks - state records           subcategory
# Background checks through permits           subcategory
# Background checks time limit                subcategory
# Bulk purchase limit                         subcategory
# Campus carry                                subcategory
# Crime gun identification                    subcategory
# Drugs                                       subcategory
# Felony                                      subcategory
# Fingerprinting                              subcategory
# Firearm removal                             subcategory
# Gun shows                                   subcategory
# Gun violence restraining orders             subcategory
# Inspections                                 subcategory
# Junk guns                                   subcategory
# Large capacity magazine ban                 subcategory
# Liability                                   subcategory
# Licensing                                   subcategory
# Location                                    subcategory
# Mental Health                               subcategory
# Misdemeanor crimes                          subcategory
# Open carry                                  subcategory
# Permitting                                  subcategory
# Personalized gun technology                 subcategory
# Prohibitors                                 subcategory
# Recordkeeping                               subcategory
# Registration                                subcategory
# Relinquishment of weapons                   subcategory
# Reporting                                   subcategory
# Restraining order                           subcategory
# Safety locks                                subcategory
# Safety training                             subcategory
# School zones                                subcategory
# Security                                    subcategory
# Stalking                                    subcategory
# Storage                                     subcategory
# Straw purchase                              subcategory
# Theft reporting                             subcategory
# Universal background checks                 subcategory
# Violent Misdemeanor                         subcategory
# Waiting period                              subcategory

# %%
# store data
policy_correlation_df = pd.concat(correlation_dfs).reset_index()
policy_correlation_df.to_csv('data/policy_incident_correlations.csv', index=False)
